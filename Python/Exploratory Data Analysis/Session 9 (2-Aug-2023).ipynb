# %% [markdown]
# # Pandas DataFrame

# %%
import pandas as pd
import numpy as np

# %%
result = {'name':          ['Nasir','Asad', 'Fahad','Zeeshan', 'Shan', 'Shoaib', 'Ali', 'Hassan', 'Yasir', 'Junaid'],
          'roll':          [11,22,33,44,55,66,77,88,99,111],
          'python':        [78,67,89,90,91,72,76,89,67,np.nan],
          'excel':         [np.nan,87,67,np.nan,78,90,76,78,90,54],
           'power_bi':     [45,67,89,87,67,90,65,67,np.nan,90],
          'pandas':        [81,85,89,87,41,45,96,56,93,78],
         'machine_learning':[96,95,84,85,82,81,74,75,96,90],
         'statistics':     [67,np.nan,45,98,75,71,70,60,90,93]}
result
# Out:
# {'name': ['Nasir',
#   'Asad',
#   'Fahad',
#   'Zeeshan',
#   'Shan',
#   'Shoaib',
#   'Ali',
#   'Hassan',
#   'Yasir',
#   'Junaid'],
#  'roll': [11, 22, 33, 44, 55, 66, 77, 88, 99, 111],
#  'python': [78, 67, 89, 90, 91, 72, 76, 89, 67, nan],
#  'excel': [nan, 87, 67, nan, 78, 90, 76, 78, 90, 54],
#  'power_bi': [45, 67, 89, 87, 67, 90, 65, 67, nan, 90],
#  'pandas': [81, 85, 89, 87, 41, 45, 96, 56, 93, 78],
#  'machine_learning': [96, 95, 84, 85, 82, 81, 74, 75, 96, 90],
#  'statistics': [67, nan, 45, 98, 75, 71, 70, 60, 90, 93]}

# %%
data  = pd.DataFrame(result)

# %%
data
# Out:
#       name  roll  python  excel  power_bi  pandas  machine_learning  \
# 0    Nasir    11    78.0    NaN      45.0      81                96
# 1     Asad    22    67.0   87.0      67.0      85                95
# 2    Fahad    33    89.0   67.0      89.0      89                84
# 3  Zeeshan    44    90.0    NaN      87.0      87                85
# 4     Shan    55    91.0   78.0      67.0      41                82
# 5   Shoaib    66    72.0   90.0      90.0      45                81
# 6      Ali    77    76.0   76.0      65.0      96                74
# 7   Hassan    88    89.0   78.0      67.0      56                75
# 8    Yasir    99    67.0   90.0       NaN      93                96
# 9   Junaid   111     NaN   54.0      90.0      78                90
#
#    statistics
# 0        67.0
# 1         NaN
# 2        45.0
# 3        98.0
# 4        75.0
# 5        71.0
# 6        70.0
# 7        60.0
# 8        90.0
# 9        93.0

# %% [markdown]
# ### Adding Columns and Rows to existing data frame

# %%
#Adding Columns: 

# will add a col total and assign 100 to each record(broadcast 100)
data['total']=600
data
# Out:
#       name  roll  python  excel  power_bi  pandas  machine_learning  \
# 0    Nasir    11    78.0    NaN      45.0      81                96
# 1     Asad    22    67.0   87.0      67.0      85                95
# 2    Fahad    33    89.0   67.0      89.0      89                84
# 3  Zeeshan    44    90.0    NaN      87.0      87                85
# 4     Shan    55    91.0   78.0      67.0      41                82
# 5   Shoaib    66    72.0   90.0      90.0      45                81
# 6      Ali    77    76.0   76.0      65.0      96                74
# 7   Hassan    88    89.0   78.0      67.0      56                75
# 8    Yasir    99    67.0   90.0       NaN      93                96
# 9   Junaid   111     NaN   54.0      90.0      78                90
#
#    statistics  total
# 0        67.0    600
# 1         NaN    600
# 2        45.0    600
# 3        98.0    600
# 4        75.0    600
# 5        71.0    600
# 6        70.0    600
# 7        60.0    600
# ...

# %%
data['obtained_marks'] = data.python+data.excel+data.power_bi+data.pandas+data.machine_learning+data.statistics

# %%
data
# Out:
#       name  roll  python  excel  power_bi  pandas  machine_learning  \
# 0    Nasir    11    78.0    NaN      45.0      81                96
# 1     Asad    22    67.0   87.0      67.0      85                95
# 2    Fahad    33    89.0   67.0      89.0      89                84
# 3  Zeeshan    44    90.0    NaN      87.0      87                85
# 4     Shan    55    91.0   78.0      67.0      41                82
# 5   Shoaib    66    72.0   90.0      90.0      45                81
# 6      Ali    77    76.0   76.0      65.0      96                74
# 7   Hassan    88    89.0   78.0      67.0      56                75
# 8    Yasir    99    67.0   90.0       NaN      93                96
# 9   Junaid   111     NaN   54.0      90.0      78                90
#
#    statistics  total  obtained_marks
# 0        67.0    600             NaN
# 1         NaN    600             NaN
# 2        45.0    600           463.0
# 3        98.0    600             NaN
# ...

# %% [raw]
# # Important:
#     NaN + NaN  === NaN
#     NaN + number === NaN
#     Number + NaN === NaN
#     Number + Number == Number

# %% [markdown]
# ### For the time Being I am recreating data so that there may not be any NaN

# %%
result = {'name':          ['Nasir','Asad', 'Fahad','Zeeshan', 'Shan', 'Shoaib', 'Ali', 'Hassan', 'Yasir', 'Junaid'],
          'roll':          [11,22,33,44,55,66,77,88,99,111],
          'python':        [78,67,89,90,91,72,76,89,67,89],
          'excel':         [78,87,67,69,78,90,76,78,90,54],
           'power_bi':     [45,67,89,87,67,90,65,67,78,90],
          'pandas':        [81,85,89,87,41,45,96,56,93,78],
         'machine_learning':[96,95,84,85,82,81,74,75,96,90],
         'statistics':     [67,96,45,98,75,71,70,60,90,93]}
df = pd.DataFrame(result)
df
# Out:
#       name  roll  python  excel  power_bi  pandas  machine_learning  \
# 0    Nasir    11      78     78        45      81                96
# 1     Asad    22      67     87        67      85                95
# 2    Fahad    33      89     67        89      89                84
# 3  Zeeshan    44      90     69        87      87                85
# 4     Shan    55      91     78        67      41                82
# 5   Shoaib    66      72     90        90      45                81
# 6      Ali    77      76     76        65      96                74
# 7   Hassan    88      89     78        67      56                75
# 8    Yasir    99      67     90        78      93                96
# 9   Junaid   111      89     54        90      78                90
#
#    statistics
# 0          67
# 1          96
# 2          45
# 3          98
# 4          75
# 5          71
# 6          70
# 7          60
# 8          90
# 9          93

# %%
df['total']  =600

# %%
df['obtained_marks'] = df.python+df.excel+df.power_bi+df.pandas+df.machine_learning+df.statistics
df
# Out:
#       name  roll  python  excel  power_bi  pandas  machine_learning  \
# 0    Nasir    11      78     78        45      81                96
# 1     Asad    22      67     87        67      85                95
# 2    Fahad    33      89     67        89      89                84
# 3  Zeeshan    44      90     69        87      87                85
# 4     Shan    55      91     78        67      41                82
# 5   Shoaib    66      72     90        90      45                81
# 6      Ali    77      76     76        65      96                74
# 7   Hassan    88      89     78        67      56                75
# 8    Yasir    99      67     90        78      93                96
# 9   Junaid   111      89     54        90      78                90
#
#    statistics  total  obtained_marks
# 0          67    600             445
# 1          96    600             497
# 2          45    600             463
# 3          98    600             516
# ...

# %%
df['percentage'] = df.obtained_marks/df.total *100
df
# Out:
#       name  roll  python  excel  power_bi  pandas  machine_learning  \
# 0    Nasir    11      78     78        45      81                96
# 1     Asad    22      67     87        67      85                95
# 2    Fahad    33      89     67        89      89                84
# 3  Zeeshan    44      90     69        87      87                85
# 4     Shan    55      91     78        67      41                82
# 5   Shoaib    66      72     90        90      45                81
# 6      Ali    77      76     76        65      96                74
# 7   Hassan    88      89     78        67      56                75
# 8    Yasir    99      67     90        78      93                96
# 9   Junaid   111      89     54        90      78                90
#
#    statistics  total  obtained_marks  percentage
# 0          67    600             445   74.166667
# 1          96    600             497   82.833333
# 2          45    600             463   77.166667
# ...

# %%
df['percentage'] = round((df.obtained_marks/df.total *100),1)
df
# Out:
#       name  roll  python  excel  power_bi  pandas  machine_learning  \
# 0    Nasir    11      78     78        45      81                96
# 1     Asad    22      67     87        67      85                95
# 2    Fahad    33      89     67        89      89                84
# 3  Zeeshan    44      90     69        87      87                85
# 4     Shan    55      91     78        67      41                82
# 5   Shoaib    66      72     90        90      45                81
# 6      Ali    77      76     76        65      96                74
# 7   Hassan    88      89     78        67      56                75
# 8    Yasir    99      67     90        78      93                96
# 9   Junaid   111      89     54        90      78                90
#
#    statistics  total  obtained_marks  percentage
# 0          67    600             445        74.2
# 1          96    600             497        82.8
# 2          45    600             463        77.2
# ...

# %%
df['grade'] = df.percentage.apply(lambda per: "A*" if per >=90 else  "A" if per >=80 else "B" if per>=70 else "C" if per>=60 else "F")

# %%
df['status'] = [(p,e,pb,pd,ml,st) for p,e,pb,pd,ml,st in zip(df.python,df.excel,df.power_bi,df.pandas,df.machine_learning,df.statistics)]

# %%
df['status'] = ["Fail in Python" if p<60 else "Fail in excel" if e<60 else "Fail in Power Bi" if pb<60 else "Fail in Pandas" if pd<60 else "Fail in MachineLearning" if ml<60 else 'Fail in stats' if st<60 else "Pass" for p,e,pb,pd,ml,st in zip(df.python,df.excel,df.power_bi,df.pandas,df.machine_learning,df.statistics)]

# %%
df
# Out:
#       name  roll  python  excel  power_bi  pandas  machine_learning  \
# 0    Nasir    11      78     78        45      81                96
# 1     Asad    22      67     87        67      85                95
# 2    Fahad    33      89     67        89      89                84
# 3  Zeeshan    44      90     69        87      87                85
# 4     Shan    55      91     78        67      41                82
# 5   Shoaib    66      72     90        90      45                81
# 6      Ali    77      76     76        65      96                74
# 7   Hassan    88      89     78        67      56                75
# 8    Yasir    99      67     90        78      93                96
# 9   Junaid   111      89     54        90      78                90
#
#    statistics  total  obtained_marks  percentage grade            status
# 0          67    600             445        74.2     B  Fail in Power Bi
# 1          96    600             497        82.8     A              Pass
# ...

# %%
alist = [12,24] # packing
alist
# Out:
# [12, 24]

# %%
apples, oranges = alist  # unpacking

# %%
apples
# Out:
# 12

# %%
oranges
# Out:
# 24

# %% [markdown]
# # List comprehension

# %%
[ a*10 for a in range(10) if a%2==0]
# Out:
# [0, 20, 40, 60, 80]

# %%
[ a*10 if a%2==0 else a for a in range(10)]
# Out:
# [0, 1, 20, 3, 40, 5, 60, 7, 80, 9]

# %% [markdown]
# # Data Cleaning
#     - Handling Missing Values
#         - Drop missing value records(row),
#         - Drop missing value feature (column)
#         - Fill missing values
#               - different methods and criteria based filling
#     - Handling Duplicates

# %%
data
# Out:
#       name  roll  python  excel  power_bi  pandas  machine_learning  \
# 0    Nasir    11    78.0    NaN      45.0      81                96
# 1     Asad    22    67.0   87.0      67.0      85                95
# 2    Fahad    33    89.0   67.0      89.0      89                84
# 3  Zeeshan    44    90.0    NaN      87.0      87                85
# 4     Shan    55    91.0   78.0      67.0      41                82
# 5   Shoaib    66    72.0   90.0      90.0      45                81
# 6      Ali    77    76.0   76.0      65.0      96                74
# 7   Hassan    88    89.0   78.0      67.0      56                75
# 8    Yasir    99    67.0   90.0       NaN      93                96
# 9   Junaid   111     NaN   54.0      90.0      78                90
#
#    statistics  total  obtained_marks
# 0        67.0    600             NaN
# 1         NaN    600             NaN
# 2        45.0    600           463.0
# 3        98.0    600             NaN
# ...

# %%
# return number of rows and columns
data.shape
# Out:
# (10, 10)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              10 non-null     object
#  1   roll              10 non-null     int64
#  2   python            9 non-null      float64
#  3   excel             8 non-null      float64
#  4   power_bi          9 non-null      float64
#  5   pandas            10 non-null     int64
#  6   machine_learning  10 non-null     int64
#  7   statistics        9 non-null      float64
#  8   total             10 non-null     int64
#  9   obtained_marks    5 non-null      float64
# dtypes: float64(5), int64(4), object(1)
# memory usage: 928.0+ bytes

# %%
data.isnull().sum()
# Out:
# name                0
# roll                0
# python              1
# excel               2
# power_bi            1
# pandas              0
# machine_learning    0
# statistics          1
# total               0
# obtained_marks      5
# dtype: int64

# %%
data.iloc[3:4,4:6] = np.nan
data.loc[[4,9,2],['pandas', 'statistics','excel']] = np.nan
data
# Out:
#       name  roll  python  excel  power_bi  pandas  machine_learning  \
# 0    Nasir    11    78.0    NaN      45.0    81.0                96
# 1     Asad    22    67.0   87.0      67.0    85.0                95
# 2    Fahad    33    89.0    NaN      89.0     NaN                84
# 3  Zeeshan    44    90.0    NaN       NaN     NaN                85
# 4     Shan    55    91.0    NaN      67.0     NaN                82
# 5   Shoaib    66    72.0   90.0      90.0    45.0                81
# 6      Ali    77    76.0   76.0      65.0    96.0                74
# 7   Hassan    88    89.0   78.0      67.0    56.0                75
# 8    Yasir    99    67.0   90.0       NaN    93.0                96
# 9   Junaid   111     NaN    NaN      90.0     NaN                90
#
#    statistics  total  obtained_marks
# 0        67.0    600             NaN
# 1         NaN    600             NaN
# 2         NaN    600           463.0
# 3        98.0    600             NaN
# ...

# %%
# drop missing value row or col
data.dropna(thresh=8)
# not dropping permanently>>>> original will not changed
# Out:
#      name  roll  python  excel  power_bi  pandas  machine_learning  \
# 0   Nasir    11    78.0    NaN      45.0    81.0                96
# 1    Asad    22    67.0   87.0      67.0    85.0                95
# 5  Shoaib    66    72.0   90.0      90.0    45.0                81
# 6     Ali    77    76.0   76.0      65.0    96.0                74
# 7  Hassan    88    89.0   78.0      67.0    56.0                75
# 8   Yasir    99    67.0   90.0       NaN    93.0                96
#
#    statistics  total  obtained_marks
# 0        67.0    600             NaN
# 1         NaN    600             NaN
# 5        71.0    600           449.0
# 6        70.0    600           457.0
# 7        60.0    600           425.0
# 8        90.0    600             NaN

# %%
data['missing'] = np.nan
data
# Out:
#       name  roll  python  excel  power_bi  pandas  machine_learning  \
# 0    Nasir    11    78.0    NaN      45.0    81.0                96
# 1     Asad    22    67.0   87.0      67.0    85.0                95
# 2    Fahad    33    89.0    NaN      89.0     NaN                84
# 3  Zeeshan    44    90.0    NaN       NaN     NaN                85
# 4     Shan    55    91.0    NaN      67.0     NaN                82
# 5   Shoaib    66    72.0   90.0      90.0    45.0                81
# 6      Ali    77    76.0   76.0      65.0    96.0                74
# 7   Hassan    88    89.0   78.0      67.0    56.0                75
# 8    Yasir    99    67.0   90.0       NaN    93.0                96
# 9   Junaid   111     NaN    NaN      90.0     NaN                90
#
#    statistics  total  obtained_marks  missing
# 0        67.0    600             NaN      NaN
# 1         NaN    600             NaN      NaN
# 2         NaN    600           463.0      NaN
# ...

# %%
data.dropna(axis=1, how='any')
# Out:
#       name  roll  machine_learning  total
# 0    Nasir    11                96    600
# 1     Asad    22                95    600
# 2    Fahad    33                84    600
# 3  Zeeshan    44                85    600
# 4     Shan    55                82    600
# 5   Shoaib    66                81    600
# 6      Ali    77                74    600
# 7   Hassan    88                75    600
# 8    Yasir    99                96    600
# 9   Junaid   111                90    600

# %%
data.dropna(axis=0, how='any')
# Out:
# Empty DataFrame
# Columns: [name, roll, python, excel, power_bi, pandas, machine_learning, statistics, total, obtained_marks, missing]
# Index: []

# %%
data.drop('missing',axis=1,inplace=True)
data
# Out:
#       name  roll  python  excel  power_bi  pandas  machine_learning  \
# 0    Nasir    11    78.0    NaN      45.0    81.0                96
# 1     Asad    22    67.0   87.0      67.0    85.0                95
# 2    Fahad    33    89.0    NaN      89.0     NaN                84
# 3  Zeeshan    44    90.0    NaN       NaN     NaN                85
# 4     Shan    55    91.0    NaN      67.0     NaN                82
# 5   Shoaib    66    72.0   90.0      90.0    45.0                81
# 6      Ali    77    76.0   76.0      65.0    96.0                74
# 7   Hassan    88    89.0   78.0      67.0    56.0                75
# 8    Yasir    99    67.0   90.0       NaN    93.0                96
# 9   Junaid   111     NaN    NaN      90.0     NaN                90
#
#    statistics  total  obtained_marks
# 0        67.0    600             NaN
# 1         NaN    600             NaN
# 2         NaN    600           463.0
# 3        98.0    600             NaN
# ...

# %% [markdown]
# # Filling the missing data

# %%
data.fillna(0)
# Out:
#       name  roll  python  excel  power_bi  pandas  machine_learning  \
# 0    Nasir    11    78.0    0.0      45.0    81.0                96
# 1     Asad    22    67.0   87.0      67.0    85.0                95
# 2    Fahad    33    89.0    0.0      89.0     0.0                84
# 3  Zeeshan    44    90.0    0.0       0.0     0.0                85
# 4     Shan    55    91.0    0.0      67.0     0.0                82
# 5   Shoaib    66    72.0   90.0      90.0    45.0                81
# 6      Ali    77    76.0   76.0      65.0    96.0                74
# 7   Hassan    88    89.0   78.0      67.0    56.0                75
# 8    Yasir    99    67.0   90.0       0.0    93.0                96
# 9   Junaid   111     0.0    0.0      90.0     0.0                90
#
#    statistics  total  obtained_marks
# 0        67.0    600             0.0
# 1         0.0    600             0.0
# 2         0.0    600           463.0
# 3        98.0    600             0.0
# ...

# %%
data.fillna({'python':10, 'excel':20, 'power_bi':30, 'pandas':40, 'machine_learning':50, 'statistics':60})
# Out:
#       name  roll  python  excel  power_bi  pandas  machine_learning  \
# 0    Nasir    11    78.0   20.0      45.0    81.0                96
# 1     Asad    22    67.0   87.0      67.0    85.0                95
# 2    Fahad    33    89.0   20.0      89.0    40.0                84
# 3  Zeeshan    44    90.0   20.0      30.0    40.0                85
# 4     Shan    55    91.0   20.0      67.0    40.0                82
# 5   Shoaib    66    72.0   90.0      90.0    45.0                81
# 6      Ali    77    76.0   76.0      65.0    96.0                74
# 7   Hassan    88    89.0   78.0      67.0    56.0                75
# 8    Yasir    99    67.0   90.0      30.0    93.0                96
# 9   Junaid   111    10.0   20.0      90.0    40.0                90
#
#    statistics  total  obtained_marks
# 0        67.0    600             NaN
# 1        60.0    600             NaN
# 2        60.0    600           463.0
# 3        98.0    600             NaN
# ...

# %%
data.fillna({'python':round(data.python.mean(),1), 'excel':round(data.excel.mean(),1), 'power_bi':round(data.power_bi.mean(),1), 'pandas':round(data.pandas.mean(),1), 'machine_learning':round(data.machine_learning.mean(),1), 'statistics':round(data.statistics.mean(),1)})
# Out:
#       name  roll  python  excel  power_bi  pandas  machine_learning  \
# 0    Nasir    11    78.0   84.2      45.0    81.0                96
# 1     Asad    22    67.0   87.0      67.0    85.0                95
# 2    Fahad    33    89.0   84.2      89.0    76.0                84
# 3  Zeeshan    44    90.0   84.2      72.5    76.0                85
# 4     Shan    55    91.0   84.2      67.0    76.0                82
# 5   Shoaib    66    72.0   90.0      90.0    45.0                81
# 6      Ali    77    76.0   76.0      65.0    96.0                74
# 7   Hassan    88    89.0   78.0      67.0    56.0                75
# 8    Yasir    99    67.0   90.0      72.5    93.0                96
# 9   Junaid   111    79.9   84.2      90.0    76.0                90
#
#    statistics  total  obtained_marks
# 0        67.0    600             NaN
# 1        76.0    600             NaN
# 2        76.0    600           463.0
# 3        98.0    600             NaN
# ...

# %%
data.python.mean()
# Out:
# 79.88888888888889

# %%
blood_gp = pd.Series(["A", "B","A+", "B+",np.nan, "O+", "A-", "A", np.nan, "A"])
blood_gp
# Out:
# 0      A
# 1      B
# 2     A+
# 3     B+
# 4    NaN
# 5     O+
# 6     A-
# 7      A
# 8    NaN
# 9      A
# dtype: object

# %%
data['blood_gp'] = blood_gp
data
# Out:
#       name  roll  python  excel  power_bi  pandas  machine_learning  \
# 0    Nasir    11    78.0    NaN      45.0    81.0                96
# 1     Asad    22    67.0   87.0      67.0    85.0                95
# 2    Fahad    33    89.0    NaN      89.0     NaN                84
# 3  Zeeshan    44    90.0    NaN       NaN     NaN                85
# 4     Shan    55    91.0    NaN      67.0     NaN                82
# 5   Shoaib    66    72.0   90.0      90.0    45.0                81
# 6      Ali    77    76.0   76.0      65.0    96.0                74
# 7   Hassan    88    89.0   78.0      67.0    56.0                75
# 8    Yasir    99    67.0   90.0       NaN    93.0                96
# 9   Junaid   111     NaN    NaN      90.0     NaN                90
#
#    statistics  total  obtained_marks blood_gp
# 0        67.0    600             NaN        A
# 1         NaN    600             NaN        B
# 2         NaN    600           463.0       A+
# ...

# %%
data.fillna({'blood_gp':data.blood_gp.mode()[0]}, inplace=True)

# %%
data
# Out:
#       name  roll  python  excel  power_bi  pandas  machine_learning  \
# 0    Nasir    11    78.0    NaN      45.0    81.0                96
# 1     Asad    22    67.0   87.0      67.0    85.0                95
# 2    Fahad    33    89.0    NaN      89.0     NaN                84
# 3  Zeeshan    44    90.0    NaN       NaN     NaN                85
# 4     Shan    55    91.0    NaN      67.0     NaN                82
# 5   Shoaib    66    72.0   90.0      90.0    45.0                81
# 6      Ali    77    76.0   76.0      65.0    96.0                74
# 7   Hassan    88    89.0   78.0      67.0    56.0                75
# 8    Yasir    99    67.0   90.0       NaN    93.0                96
# 9   Junaid   111     NaN    NaN      90.0     NaN                90
#
#    statistics  total  obtained_marks blood_gp
# 0        67.0    600             NaN        A
# 1         NaN    600             NaN        B
# 2         NaN    600           463.0       A+
# ...

# %%
# data.fillna()

# %%
sales = pd.read_excel('data/SaleData.xlsx',sheet_name=1)
sales
# Out:
#     OrderDate   Region  Manager   SalesMan          Item  Units  Unit_price  \
# 0  2019-08-07  Central  Hermann     Shelli   Video Games     42        58.5
# 1  2019-08-24     West  Timothy    Stephen          Desk      3       125.0
# 2  2019-09-10  Central  Timothy      David    Television      7      1198.0
# 3  2018-01-06     East   Martha  Alexander    Television     95      1198.0
# 4  2018-01-23  Central  Hermann     Shelli  Home Theater     50       500.0
# 5  2018-02-09  Central  Hermann       Luis    Television     36      1198.0
# 6  2018-02-26  Central  Timothy      David    Cell Phone     27       225.0
# 7  2018-03-15     West  Timothy    Stephen    Television     56      1198.0
# 8  2018-04-01     East   Martha  Alexander  Home Theater     60       500.0
# 9  2018-04-18  Central   Martha     Steven    Television     75      1198.0
# 10 2018-05-05  Central  Hermann       Luis    Television     90      1198.0
# ...

# %%
sales.shape
# Out:
# (52, 8)

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   OrderDate   52 non-null     datetime64[ns]
#  1   Region      52 non-null     object
#  2   Manager     52 non-null     object
#  3   SalesMan    52 non-null     object
#  4   Item        52 non-null     object
#  5   Units       52 non-null     int64
#  6   Unit_price  52 non-null     float64
#  7   Sale_amt    52 non-null     float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 3.4+ KB

# %%
sales.isnull().sum()
# Out:
# OrderDate     0
# Region        0
# Manager       0
# SalesMan      0
# Item          0
# Units         0
# Unit_price    0
# Sale_amt      0
# dtype: int64

# %%
sales[sales.duplicated()]
# Out:
#     OrderDate   Region  Manager SalesMan          Item  Units  Unit_price  \
# 37 2019-08-07  Central  Hermann   Shelli   Video Games     42        58.5
# 38 2019-08-24     West  Timothy  Stephen          Desk      3       125.0
# 39 2019-09-10  Central  Timothy    David    Television      7      1198.0
# 46 2019-04-27     East   Martha    Diana    Cell Phone     96       225.0
# 47 2019-02-01  Central  Douglas     John  Home Theater     87       500.0
# 48 2019-03-24  Central  Hermann     Luis   Video Games     50        58.5
# 49 2019-04-10  Central   Martha   Steven    Television     66      1198.0
# 50 2019-04-27     East   Martha    Diana    Cell Phone     96       225.0
# 51 2019-05-14  Central  Timothy    David    Television     53      1198.0
#
#     Sale_amt
# 37    2457.0
# 38     375.0
# 39    8386.0
# 46   21600.0
# 47   43500.0
# 48    2925.0
# 49   79068.0
# 50   21600.0
# 51   63494.0

# %%
sales.duplicated().sum()
# Out:
# 9

# %%
sales.drop_duplicates(inplace=True)

# %%
sales.duplicated().sum()
# Out:
# 0

# %%
sales.duplicated(subset=['Region','Manager','SalesMan']).sum()
# Out:
# 32

# %% [markdown]
# # Data Wrangling
#     - Preparing a new data using some data from different sourses
#         - concatenation
#         - merging data

# %%
df1  = pd.read_excel('data/test_data.xlsx',sheet_name=0)
df2  = pd.read_excel('data/test_data.xlsx',sheet_name=1)
df3  = pd.read_excel('data/test_data.xlsx',sheet_name=2)

# %%
df1
# Out:
#    sales_man_id sales_man_name sales_man_city  product_id manager
# 0             1           Asad        Karachi         123   Jawed
# 1             2         Sumair         Lahore         123   Jawed
# 2             3         Farjad        Karachi         145   Najam
# 3             4         Hassan         Lahore         567   Najam
# 4             5          Nasir      Hyderabad         234   Jawed
# 5             6         Kashif      Hyderabad         234  Faisal
# 6             7           Sana         Lahore         567  Faisal
# 7             8         Fatima        Karachi         345   Najam
# 8             9       Abdullah        Karachi         123  Faisal

# %%
df2
# Out:
#    sales_man_id sales_man_name sales_man_city  product_id manager
# 0            11          Ahmed        Karachi         123   Jawed
# 1            22           Umer         Lahore         123   Jawed
# 2            33        Huzaifa        Karachi         145   Najam
# 3            44           Asad         Lahore         567   Najam
# 4            55        Hussain      Hyderabad         234   Jawed
# 5            66            Ali      Hyderabad         234  Faisal
# 6            77          Sadaf         Lahore         567  Faisal
# 7            88          Kiran        Karachi         345   Najam
# 8            99            Ali        Karachi         123  Faisal

# %%
df3
# Out:
#   sales_man_name Region   Sales  Amount
# 0           Asad       A    100   100000
# 1       Hussain        B    300   450000
# 2            Ali       C    234   125000
# 3           Sana       D    231   652000
# 4        Fatima        E    324   145000
# 5         Kashif       F    123   825000
# 6         Hassan       G    129   125000
# 7          Almas       H    345   325600
# 8          Fahan       I    400   895200

# %% [markdown]
# # Concatenating data frames

# %%
vertical_concatinated = pd.concat([df1,df2],axis=0)
vertical_concatinated
# Out:
#    sales_man_id sales_man_name sales_man_city  product_id manager
# 0             1           Asad        Karachi         123   Jawed
# 1             2         Sumair         Lahore         123   Jawed
# 2             3         Farjad        Karachi         145   Najam
# 3             4         Hassan         Lahore         567   Najam
# 4             5          Nasir      Hyderabad         234   Jawed
# 5             6         Kashif      Hyderabad         234  Faisal
# 6             7           Sana         Lahore         567  Faisal
# 7             8         Fatima        Karachi         345   Najam
# 8             9       Abdullah        Karachi         123  Faisal
# 0            11          Ahmed        Karachi         123   Jawed
# 1            22           Umer         Lahore         123   Jawed
# 2            33        Huzaifa        Karachi         145   Najam
# 3            44           Asad         Lahore         567   Najam
# ...

# %%
vertical_concatinated.reset_index(drop=True,inplace=True)

# %%
vertical_concatinated
# Out:
#     sales_man_id sales_man_name sales_man_city  product_id manager
# 0              1           Asad        Karachi         123   Jawed
# 1              2         Sumair         Lahore         123   Jawed
# 2              3         Farjad        Karachi         145   Najam
# 3              4         Hassan         Lahore         567   Najam
# 4              5          Nasir      Hyderabad         234   Jawed
# 5              6         Kashif      Hyderabad         234  Faisal
# 6              7           Sana         Lahore         567  Faisal
# 7              8         Fatima        Karachi         345   Najam
# 8              9       Abdullah        Karachi         123  Faisal
# 9             11          Ahmed        Karachi         123   Jawed
# 10            22           Umer         Lahore         123   Jawed
# 11            33        Huzaifa        Karachi         145   Najam
# 12            44           Asad         Lahore         567   Najam
# ...

# %%
df1
# Out:
#    sales_man_id sales_man_name sales_man_city  product_id manager
# 0             1           Asad        Karachi         123   Jawed
# 1             2         Sumair         Lahore         123   Jawed
# 2             3         Farjad        Karachi         145   Najam
# 3             4         Hassan         Lahore         567   Najam
# 4             5          Nasir      Hyderabad         234   Jawed
# 5             6         Kashif      Hyderabad         234  Faisal
# 6             7           Sana         Lahore         567  Faisal
# 7             8         Fatima        Karachi         345   Najam
# 8             9       Abdullah        Karachi         123  Faisal

# %%
df2
# Out:
#    sales_man_id sales_man_name sales_man_city  product_id manager
# 0            11          Ahmed        Karachi         123   Jawed
# 1            22           Umer         Lahore         123   Jawed
# 2            33        Huzaifa        Karachi         145   Najam
# 3            44           Asad         Lahore         567   Najam
# 4            55        Hussain      Hyderabad         234   Jawed
# 5            66            Ali      Hyderabad         234  Faisal
# 6            77          Sadaf         Lahore         567  Faisal
# 7            88          Kiran        Karachi         345   Najam
# 8            99            Ali        Karachi         123  Faisal

# %%
horizontal_concatinated = pd.concat([df1,df2],axis=1)
horizontal_concatinated
# Out:
#    sales_man_id sales_man_name sales_man_city  product_id manager  \
# 0             1           Asad        Karachi         123   Jawed
# 1             2         Sumair         Lahore         123   Jawed
# 2             3         Farjad        Karachi         145   Najam
# 3             4         Hassan         Lahore         567   Najam
# 4             5          Nasir      Hyderabad         234   Jawed
# 5             6         Kashif      Hyderabad         234  Faisal
# 6             7           Sana         Lahore         567  Faisal
# 7             8         Fatima        Karachi         345   Najam
# 8             9       Abdullah        Karachi         123  Faisal
#
#    sales_man_id sales_man_name sales_man_city  product_id manager
# 0            11          Ahmed        Karachi         123   Jawed
# 1            22           Umer         Lahore         123   Jawed
# 2            33        Huzaifa        Karachi         145   Najam
# ...

# %%
horizontal_concatinated = pd.concat([df1,df3],axis=1)
horizontal_concatinated
# Out:
#    sales_man_id sales_man_name sales_man_city  product_id manager  \
# 0             1           Asad        Karachi         123   Jawed
# 1             2         Sumair         Lahore         123   Jawed
# 2             3         Farjad        Karachi         145   Najam
# 3             4         Hassan         Lahore         567   Najam
# 4             5          Nasir      Hyderabad         234   Jawed
# 5             6         Kashif      Hyderabad         234  Faisal
# 6             7           Sana         Lahore         567  Faisal
# 7             8         Fatima        Karachi         345   Najam
# 8             9       Abdullah        Karachi         123  Faisal
#
#   sales_man_name Region   Sales  Amount
# 0           Asad       A    100   100000
# 1       Hussain        B    300   450000
# 2            Ali       C    234   125000
# 3           Sana       D    231   652000
# 4        Fatima        E    324   145000
# 5         Kashif       F    123   825000
# ...
